# %%
import pandas as pd
df = pd.read_csv ("Motor_vehicle_insurance_cleaned.csv")
df
# Out:
#        ID;Date_start_contract;Date_last_renewal;Date_next_renewal;Date_birth;Date_driving_licence;Distribution_channel;Seniority;Policies_in_force;Max_policies;Max_products;Lapse;Date_lapse;Payment;Premium;Cost_claims_year;N_claims_year;N_claims_history;R_Claims_history;Type_risk;Area;Second_driver;Year_matriculation;Power;Cylinder_capacity;Value_vehicle;N_doors;Type_fuel;Length;Weight
# 0       1;05/11/2015;05/11/2015;05/11/2016;15/04/1956;...
# 1       1;05/11/2015;05/11/2016;05/11/2017;15/04/1956;...
# 2       1;05/11/2015;05/11/2017;05/11/2018;15/04/1956;...
# 3       1;05/11/2015;05/11/2018;05/11/2019;15/04/1956;...
# 4       2;26/09/2017;26/09/2017;26/09/2018;15/04/1956;...
# ...                                                   ...
# 105550  53498;30/07/2018;30/07/2018;30/07/2019;25/07/1...
# 105551  53499;16/08/2018;16/08/2018;16/08/2019;08/12/1...
# 105552  53500;21/11/2018;21/11/2018;21/11/2019;01/04/1...
# 105553  53501;21/11/2018;21/11/2018;21/11/2019;15/09/1...
# ...

# %%
import pandas as pd

# Load your CSV file (replace with your actual file path)
file_path = r"C:\Users\NICE\Downloads\VolumeMomentum_Project_Folder\Dataset of an actual motor vehicle insurance portfolio (1)\Dataset of an actual motor vehicle insurance portfolio\Motor vehicle insurance data.csv"

# Read with semicolon separator
df = pd.read_csv(file_path, sep=';')

# Show first few rows
print(df.head())
print(df.shape)
df
# Out:
#    ID Date_start_contract Date_last_renewal Date_next_renewal  Date_birth  \
# 0   1          05/11/2015        05/11/2015        05/11/2016  15/04/1956
# 1   1          05/11/2015        05/11/2016        05/11/2017  15/04/1956
# 2   1          05/11/2015        05/11/2017        05/11/2018  15/04/1956
# 3   1          05/11/2015        05/11/2018        05/11/2019  15/04/1956
# 4   2          26/09/2017        26/09/2017        26/09/2018  15/04/1956
#
#   Date_driving_licence  Distribution_channel  Seniority  Policies_in_force  \
# 0           20/03/1976                     0          4                  1
# 1           20/03/1976                     0          4                  1
# 2           20/03/1976                     0          4                  2
# 3           20/03/1976                     0          4                  2
# 4           20/03/1976                     0          4                  2
#
# ...

# %%
import pandas as pd

# Correct Windows file path (notice the 'r' before the string — this makes it a raw string)
file_path = r"C:\Users\NICE\Downloads\VolumeMomentum_Project_Folder\Dataset of an actual motor vehicle insurance portfolio (1)\Dataset of an actual motor vehicle insurance portfolio\Motor vehicle insurance data.csv"

# Read the dataset (semicolon-separated)
df = pd.read_csv(file_path, sep=';')

# Display first few rows and shape
print(df.head())
print("Dataset shape:", df.shape)

# Save a cleaned version (semicolon-separated)
output_path = r"C:\Users\NICE\Downloads\VolumeMomentum_Project_Folder\Dataset of an actual motor vehicle insurance portfolio (1)\Dataset of an actual motor vehicle insurance portfolio\Motor_vehicle_insurance_cleaned.csv"
df.to_csv(output_path, sep=';', index=False)

print("✅ Cleaned dataset saved at:", output_path)
# Out:
#    ID Date_start_contract Date_last_renewal Date_next_renewal  Date_birth  \
# 0   1          05/11/2015        05/11/2015        05/11/2016  15/04/1956
# 1   1          05/11/2015        05/11/2016        05/11/2017  15/04/1956
# 2   1          05/11/2015        05/11/2017        05/11/2018  15/04/1956
# 3   1          05/11/2015        05/11/2018        05/11/2019  15/04/1956
# 4   2          26/09/2017        26/09/2017        26/09/2018  15/04/1956
#
#   Date_driving_licence  Distribution_channel  Seniority  Policies_in_force  \
# 0           20/03/1976                     0          4                  1
# 1           20/03/1976                     0          4                  1
# 2           20/03/1976                     0          4                  2
# 3           20/03/1976                     0          4                  2
# 4           20/03/1976                     0          4                  2
#
# ...

# %%
df.head(2)
# Out:
#    ID Date_start_contract Date_last_renewal Date_next_renewal  Date_birth  \
# 0   1          05/11/2015        05/11/2015        05/11/2016  15/04/1956
# 1   1          05/11/2015        05/11/2016        05/11/2017  15/04/1956
#
#   Date_driving_licence  Distribution_channel  Seniority  Policies_in_force  \
# 0           20/03/1976                     0          4                  1
# 1           20/03/1976                     0          4                  1
#
#    Max_policies  ...  Area  Second_driver Year_matriculation  Power  \
# 0             2  ...     0              0               2004     80
# 1             2  ...     0              0               2004     80
#
#    Cylinder_capacity  Value_vehicle  N_doors  Type_fuel  Length  Weight
# 0                599         7068.0        0          P     NaN     190
# 1                599         7068.0        0          P     NaN     190
#
# [2 rows x 30 columns]

# %%
 # Final_Data_Set_For_Insurance.csv
import pandas as pd
df = pd.read_csv ("Final_Data_Set_for_Insurance.csv")
df
# Out:
# C:\Users\NICE\AppData\Local\Temp\ipykernel_14940\3009601558.py:3: DtypeWarning: Columns (31,39,41,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv ("Final_Data_Set_for_Insurance.csv")
#            ID Date_start_contract Date_last_renewal Date_next_renewal  \
# 0           1          05/11/2015        05/11/2015        05/11/2016
# 1           1          05/11/2015        05/11/2016        05/11/2017
# 2           1          05/11/2015        05/11/2017        05/11/2018
# 3           1          05/11/2015        05/11/2018        05/11/2019
# 4           2          26/09/2017        26/09/2017        26/09/2018
# ...       ...                 ...               ...               ...
# 105550  53498          30/07/2018        30/07/2018        30/07/2019
# 105551  53499          16/08/2018        16/08/2018        16/08/2019
# 105552  53500          21/11/2018        21/11/2018        21/11/2019
# ...

# %% [markdown]
# ## Work Start Form Here

# %% [markdown]
# ### Data Set Name - Insurance_dataSet.csv

# %%
import pandas as pd
import numpy as np
df = pd.read_csv ("Insurance_dataSet.csv")
df
# Out:
#       ID Date_start_contract Date_last_renewal Date_next_renewal Date_birth  \
# 0      1           11/5/2015         11/5/2015         11/5/2016  4/15/1956
# 1      1           11/5/2015         11/5/2016         11/5/2017  4/15/1956
# 2      1           11/5/2015         11/5/2017         11/5/2018  4/15/1956
# 3      1           11/5/2015         11/5/2018         11/5/2019  4/15/1956
# 4      2           9/26/2017         9/26/2017         9/26/2018  4/15/1956
# ..   ...                 ...               ...               ...        ...
# 995  498           11/2/2017         11/2/2017         11/2/2018  8/15/1957
# 996  498           11/2/2017         11/2/2018         11/2/2019  8/15/1957
# 997  499           3/13/2012         3/13/2016         3/13/2017  12/1/1957
# 998  499           3/13/2012         3/13/2017         3/13/2018  12/1/1957
# 999  500           2/19/2018         2/19/2018         2/19/2019  9/20/1957
#
# ...

# %%
# Vehicle_ID
df['Vehicle_ID'] = df['auto_make'].astype(str) + "_" + df['auto_model'].astype(str) + "_" + df['auto_year'].astype(str) + "_" + df['policy_number'].astype(str)

# Payment_history (simulated)
df['Payment_history'] = np.where(df['policy_annual_premium'] > 1000, 'On-time',
                          np.where(df['policy_annual_premium'] > 500, 'Late', 'Missed'))

# Interaction_score
df['Interaction_score'] = (
    df['authorities_contacted'].apply(lambda x: 1 if x == 'Yes' else 0) +
    df['witnesses'].fillna(0) +
    df['police_report_available'].apply(lambda x: 1 if x == 'Yes' else 0)
)

# Renewed (simulated)
df['Renewed'] = np.where(
    (df['Seniority'] > 2) & (df['policy_annual_premium'] > 500),
    1, 0
)
df
# Out:
#       ID Date_start_contract Date_last_renewal Date_next_renewal Date_birth  \
# 0      1           11/5/2015         11/5/2015         11/5/2016  4/15/1956
# 1      1           11/5/2015         11/5/2016         11/5/2017  4/15/1956
# 2      1           11/5/2015         11/5/2017         11/5/2018  4/15/1956
# 3      1           11/5/2015         11/5/2018         11/5/2019  4/15/1956
# 4      2           9/26/2017         9/26/2017         9/26/2018  4/15/1956
# ..   ...                 ...               ...               ...        ...
# 995  498           11/2/2017         11/2/2017         11/2/2018  8/15/1957
# 996  498           11/2/2017         11/2/2018         11/2/2019  8/15/1957
# 997  499           3/13/2012         3/13/2016         3/13/2017  12/1/1957
# 998  499           3/13/2012         3/13/2017         3/13/2018  12/1/1957
# 999  500           2/19/2018         2/19/2018         2/19/2019  9/20/1957
#
# ...

# %%
print("Total columns:", len(df.columns))
print("Column names:", df.columns.tolist())
# Out:
# Total columns: 50
# Column names: ['ID', 'Date_start_contract', 'Date_last_renewal', 'Date_next_renewal', 'Date_birth', 'Date_driving_licence', 'Distribution_channel', 'Seniority', 'Policies_in_force', 'Max_policies', 'Max_products', 'Lapse', 'Date_lapse', 'Payment', 'Premium', 'Cost_claims_year', 'N_claims_year', 'N_claims_history', 'R_Claims_history', 'Type_risk', 'Area', 'Second_driver', 'Year_matriculation', 'Power', 'Cylinder_capacity', 'Value_vehicle', 'N_doors', 'Type_fuel', 'Length', 'Weight', 'bodily_injuries', 'property_damage', 'injury_claim', 'property_claim', 'vehicle_claim', 'total_claim_amount', 'policy_annual_premium', 'policy_deductable', 'umbrella_limit', 'authorities_contacted', 'witnesses', 'police_report_available', 'policy_number', 'auto_make', 'auto_model', 'auto_year', 'Vehicle_ID', 'Payment_history', 'Interaction_score', 'Renewed']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 50 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       1000 non-null   int64
#  1   Date_start_contract      1000 non-null   object
#  2   Date_last_renewal        1000 non-null   object
#  3   Date_next_renewal        1000 non-null   object
#  4   Date_birth               1000 non-null   object
#  5   Date_driving_licence     1000 non-null   object
#  6   Distribution_channel     1000 non-null   int64
#  7   Seniority                1000 non-null   int64
#  8   Policies_in_force        1000 non-null   int64
#  9   Max_policies             1000 non-null   int64
#  10  Max_products             1000 non-null   int64
#  11  Lapse                    1000 non-null   int64
#  12  Date_lapse               412 non-null    object
#  13  Payment                  1000 non-null   int64
# ...

# %%
df.describe()
# Out:
#                 ID  Distribution_channel    Seniority  Policies_in_force  \
# count  1000.000000           1000.000000  1000.000000        1000.000000
# mean    255.379000              0.436000     8.101000           1.495000
# std     147.360417              0.496135     7.155837           0.964835
# min       1.000000              0.000000     1.000000           1.000000
# 25%     128.750000              0.000000     3.000000           1.000000
# 50%     260.500000              0.000000     5.000000           1.000000
# 75%     381.250000              1.000000    12.000000           2.000000
# max     500.000000              1.000000    40.000000           8.000000
#
#        Max_policies  Max_products        Lapse      Payment      Premium  \
# count   1000.000000   1000.000000  1000.000000  1000.000000  1000.000000
# mean       1.951000      1.057000     0.302000     0.246000   287.067180
# std        1.159286      0.248622     0.561348     0.430894   137.973308
# ...

# %%
df.isnull().sum() # Date_lapse  Type_fuel Length authorities_contacted
# Out:
# ID                           0
# Date_start_contract          0
# Date_last_renewal            0
# Date_next_renewal            0
# Date_birth                   0
# Date_driving_licence         0
# Distribution_channel         0
# Seniority                    0
# Policies_in_force            0
# Max_policies                 0
# Max_products                 0
# Lapse                        0
# Date_lapse                 588
# Payment                      0
# Premium                      0
# Cost_claims_year             0
# N_claims_year                0
# N_claims_history             0
# R_Claims_history             0
# Type_risk                    0
# Area                         0
# Second_driver                0
# Year_matriculation           0
# Power                        0
# Cylinder_capacity            0
# Value_vehicle                0
# N_doors                      0
# Type_fuel                   15
# Length                     145
# Weight                       0
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Date_start_contract', 'Date_last_renewal', 'Date_next_renewal',
#        'Date_birth', 'Date_driving_licence', 'Distribution_channel',
#        'Seniority', 'Policies_in_force', 'Max_policies', 'Max_products',
#        'Lapse', 'Date_lapse', 'Payment', 'Premium', 'Cost_claims_year',
#        'N_claims_year', 'N_claims_history', 'R_Claims_history', 'Type_risk',
#        'Area', 'Second_driver', 'Year_matriculation', 'Power',
#        'Cylinder_capacity', 'Value_vehicle', 'N_doors', 'Type_fuel', 'Length',
#        'Weight', 'bodily_injuries', 'property_damage', 'injury_claim',
#        'property_claim', 'vehicle_claim', 'total_claim_amount',
#        'policy_annual_premium', 'policy_deductable', 'umbrella_limit',
#        'authorities_contacted', 'witnesses', 'police_report_available',
#        'policy_number', 'auto_make', 'auto_model', 'auto_year', 'Vehicle_ID',
#        'Payment_history', 'Interaction_score', 'Renewed'],
#       dtype='object')

# %%
df[['Date_lapse', 'Type_fuel', 'Length', 'authorities_contacted']]
# Out:
#     Date_lapse Type_fuel  Length authorities_contacted
# 0          NaN         P     NaN                Police
# 1          NaN         P     NaN                Police
# 2          NaN         P     NaN                Police
# 3          NaN         P     NaN                Police
# 4          NaN         P     NaN                   NaN
# ..         ...       ...     ...                   ...
# 995        NaN         D   3.780                  Fire
# 996        NaN         D   3.780                  Fire
# 997  3/13/2017         D   4.188                Police
# 998  3/13/2017         D   4.188                 Other
# 999        NaN         D   3.741                Police
#
# [1000 rows x 4 columns]

# %%
df[['Date_lapse', 'Type_fuel', 'Length', 'authorities_contacted']].dtypes
# Out:
# Date_lapse                object
# Type_fuel                 object
# Length                   float64
# authorities_contacted     object
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd

# List of columns
categorical_cols = ['Date_lapse', 'Type_fuel', 'authorities_contacted']
numeric_cols = ['Length']

# Fill NaN values for categorical columns with their mode (most frequent value)
for col in categorical_cols:
    df[col].fillna(df[col].mode()[0], inplace=True)

# Fill NaN values for numeric columns with their mean
for col in numeric_cols:
    df[col].fillna(df[col].mean(), inplace=True)

# Label Encoding for categorical columns
le = LabelEncoder()
for col in categorical_cols:
    df[col] = le.fit_transform(df[col].astype(str))

# Verify result
print(df.dtypes)
print(df.head())
# Out:
# ID                           int64
# Date_start_contract         object
# Date_last_renewal           object
# Date_next_renewal           object
# Date_birth                  object
# Date_driving_licence        object
# Distribution_channel         int64
# Seniority                    int64
# Policies_in_force            int64
# Max_policies                 int64
# Max_products                 int64
# Lapse                        int64
# Date_lapse                   int32
# Payment                      int64
# Premium                    float64
# Cost_claims_year           float64
# N_claims_year                int64
# N_claims_history             int64
# R_Claims_history           float64
# Type_risk                    int64
# Area                         int64
# Second_driver                int64
# Year_matriculation           int64
# Power                        int64
# Cylinder_capacity            int64
# Value_vehicle              float64
# N_doors                      int64
# ...

# %%
df.isnull().sum()
# Out:
# ID                         0
# Date_start_contract        0
# Date_last_renewal          0
# Date_next_renewal          0
# Date_birth                 0
# Date_driving_licence       0
# Distribution_channel       0
# Seniority                  0
# Policies_in_force          0
# Max_policies               0
# Max_products               0
# Lapse                      0
# Date_lapse                 0
# Payment                    0
# Premium                    0
# Cost_claims_year           0
# N_claims_year              0
# N_claims_history           0
# R_Claims_history           0
# Type_risk                  0
# Area                       0
# Second_driver              0
# Year_matriculation         0
# Power                      0
# Cylinder_capacity          0
# Value_vehicle              0
# N_doors                    0
# Type_fuel                  0
# Length                     0
# Weight                     0
# bodily_injuries            0
# property_damage            0
# ...

# %%
df[['Date_lapse', 'Type_fuel', 'Length', 'authorities_contacted']].isnull().sum()
# Out:
# Date_lapse               0
# Type_fuel                0
# Length                   0
# authorities_contacted    0
# dtype: int64

# %%
df
# Out:
#       ID Date_start_contract Date_last_renewal Date_next_renewal Date_birth  \
# 0      1           11/5/2015         11/5/2015         11/5/2016  4/15/1956
# 1      1           11/5/2015         11/5/2016         11/5/2017  4/15/1956
# 2      1           11/5/2015         11/5/2017         11/5/2018  4/15/1956
# 3      1           11/5/2015         11/5/2018         11/5/2019  4/15/1956
# 4      2           9/26/2017         9/26/2017         9/26/2018  4/15/1956
# ..   ...                 ...               ...               ...        ...
# 995  498           11/2/2017         11/2/2017         11/2/2018  8/15/1957
# 996  498           11/2/2017         11/2/2018         11/2/2019  8/15/1957
# 997  499           3/13/2012         3/13/2016         3/13/2017  12/1/1957
# 998  499           3/13/2012         3/13/2017         3/13/2018  12/1/1957
# 999  500           2/19/2018         2/19/2018         2/19/2019  9/20/1957
#
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Date_start_contract', 'Date_last_renewal', 'Date_next_renewal',
#        'Date_birth', 'Date_driving_licence', 'Distribution_channel',
#        'Seniority', 'Policies_in_force', 'Max_policies', 'Max_products',
#        'Lapse', 'Date_lapse', 'Payment', 'Premium', 'Cost_claims_year',
#        'N_claims_year', 'N_claims_history', 'R_Claims_history', 'Type_risk',
#        'Area', 'Second_driver', 'Year_matriculation', 'Power',
#        'Cylinder_capacity', 'Value_vehicle', 'N_doors', 'Type_fuel', 'Length',
#        'Weight', 'bodily_injuries', 'property_damage', 'injury_claim',
#        'property_claim', 'vehicle_claim', 'total_claim_amount',
#        'policy_annual_premium', 'policy_deductable', 'umbrella_limit',
#        'authorities_contacted', 'witnesses', 'police_report_available',
#        'policy_number', 'auto_make', 'auto_model', 'auto_year', 'Vehicle_ID',
#        'Payment_history', 'Interaction_score', 'Renewed'],
#       dtype='object')

# %% [markdown]
# ## Ml Part Of the code

# %%
# Step 1: Import Libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
print(df.shape)
print(df.dtypes)
print(df['Lapse'].value_counts())

df.drop_duplicates(inplace=True)
df.fillna(0, inplace=True)
# Out:
# (1000, 50)
# ID                           int64
# Date_start_contract         object
# Date_last_renewal           object
# Date_next_renewal           object
# Date_birth                  object
# Date_driving_licence        object
# Distribution_channel         int64
# Seniority                    int64
# Policies_in_force            int64
# Max_policies                 int64
# Max_products                 int64
# Lapse                        int64
# Date_lapse                   int32
# Payment                      int64
# Premium                    float64
# Cost_claims_year           float64
# N_claims_year                int64
# N_claims_history             int64
# R_Claims_history           float64
# Type_risk                    int64
# Area                         int64
# Second_driver                int64
# Year_matriculation           int64
# Power                        int64
# Cylinder_capacity            int64
# Value_vehicle              float64
# ...

# %%
df.isnull().sum()
# Out:
# ID                         0
# Date_start_contract        0
# Date_last_renewal          0
# Date_next_renewal          0
# Date_birth                 0
# Date_driving_licence       0
# Distribution_channel       0
# Seniority                  0
# Policies_in_force          0
# Max_policies               0
# Max_products               0
# Lapse                      0
# Date_lapse                 0
# Payment                    0
# Premium                    0
# Cost_claims_year           0
# N_claims_year              0
# N_claims_history           0
# R_Claims_history           0
# Type_risk                  0
# Area                       0
# Second_driver              0
# Year_matriculation         0
# Power                      0
# Cylinder_capacity          0
# Value_vehicle              0
# N_doors                    0
# Type_fuel                  0
# Length                     0
# Weight                     0
# bodily_injuries            0
# property_damage            0
# ...

# %%
df.head(1)
# Out:
#    ID Date_start_contract Date_last_renewal Date_next_renewal Date_birth  \
# 0   1           11/5/2015         11/5/2015         11/5/2016  4/15/1956
#
#   Date_driving_licence  Distribution_channel  Seniority  Policies_in_force  \
# 0            3/20/1976                     0          4                  1
#
#    Max_policies  ...  witnesses  police_report_available  policy_number  \
# 0             2  ...          2                      YES         521585
#
#    auto_make  auto_model  auto_year            Vehicle_ID  Payment_history  \
# 0       Saab         92x       2004  Saab_92x_2004_521585          On-time
#
#    Interaction_score  Renewed
# 0                  2        1
#
# [1 rows x 50 columns]

# %%
# Step 3: Feature Engineering (if not already done)
df['Claim_ratio'] = df['total_claim_amount'] / df['policy_annual_premium']

# Step 4: Encode Categorical Variables
df_encoded = pd.get_dummies(df, columns=['Distribution_channel', 'Payment_history'], drop_first=True)

# Step 5: Select Features and Target
X = df_encoded[[
    'policy_annual_premium',
    'total_claim_amount',
    'Interaction_score',
    'Seniority',
    'Policies_in_force',
    'umbrella_limit',
    'Claim_ratio'
] + [col for col in df_encoded.columns if col.startswith('Distribution_channel_') or col.startswith('Payment_history_')]]

y = df_encoded['Renewed']

# Step 6: Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Step 7: Train Model
model = RandomForestClassifier()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# Step 8: Evaluate Model
print("✅ Accuracy:", accuracy_score(y_test, y_pred))
print("📊 Classification Report:\n", classification_report(y_test, y_pred))

# Step 9: Predict Renewal Probabilities
df['Renewal_Probability'] = model.predict_proba(X)[:, 1]

# Step 10: Save Updated Dataset
df.to_csv("Insurance_dataSet_with_predictions.csv", index=False)
# Out:
# ✅ Accuracy: 1.0
# 📊 Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        52
#            1       1.00      1.00      1.00       248
#
#     accuracy                           1.00       300
#    macro avg       1.00      1.00      1.00       300
# weighted avg       1.00      1.00      1.00       300

# %%
from sklearn.linear_model import LogisticRegression
model_lr = LogisticRegression(max_iter=500)
model_lr.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=500)

# %%
from sklearn.ensemble import RandomForestClassifier
model_rf = RandomForestClassifier(n_estimators=200, random_state=42)
model_rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200, random_state=42)

# %%
from xgboost import XGBClassifier
model_xgb = XGBClassifier()
model_xgb.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

y_pred = model_rf.predict(X_test)
print(classification_report(y_test, y_pred))
print("ROC-AUC Score:", roc_auc_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        52
#            1       1.00      1.00      1.00       248
#
#     accuracy                           1.00       300
#    macro avg       1.00      1.00      1.00       300
# weighted avg       1.00      1.00      1.00       300
#
# ROC-AUC Score: 1.0

# %%
import matplotlib.pyplot as plt

feature_importance = pd.Series(model_rf.feature_importances_, index=X.columns)
feature_importance.nlargest(10).plot(kind='barh')
plt.title('Top 10 Important Features')
plt.show()

# %% [markdown]
# # streamlit_app.py
# import streamlit as st
# import pandas as pd
# import pickle
#
# model = pickle.load(open('model_rf.pkl', 'rb'))
#
# st.title("Insurance Policy Renewal Predictor")
#
# payment = st.number_input("Payment Amount")
# premium = st.number_input("Policy Premium")
# claims = st.number_input("Number of Claims this Year")
#
# input_data = pd.DataFrame([[payment, premium, claims]],
#                           columns=['Payment', 'Premium', 'N_claims_year'])
#
# prob = model.predict_proba(input_data)[0][1]
# st.write(f"### Renewal Probability: {prob:.2%}")

# %%
#streamlit run streamlit_app.py

# %% [markdown]
# # 8. Evaluate Model

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        52
#            1       1.00      1.00      1.00       248
#
#     accuracy                           1.00       300
#    macro avg       1.00      1.00      1.00       300
# weighted avg       1.00      1.00      1.00       300

# %%
# Import libraries
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score, r2_score

# Initialize models
model_lr = LogisticRegression(max_iter=500)
model_rf = RandomForestClassifier(n_estimators=200, random_state=42)
model_xgb = XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42)

# Train models
model_lr.fit(X_train, y_train)
model_rf.fit(X_train, y_train)
model_xgb.fit(X_train, y_train)

# Predictions
y_pred_lr = model_lr.predict(X_test)
y_pred_rf = model_rf.predict(X_test)
y_pred_xgb = model_xgb.predict(X_test)

# Accuracy Scores
acc_lr = accuracy_score(y_test, y_pred_lr)
acc_rf = accuracy_score(y_test, y_pred_rf)
acc_xgb = accuracy_score(y_test, y_pred_xgb)

# ROC-AUC Scores
roc_lr = roc_auc_score(y_test, y_pred_lr)
roc_rf = roc_auc_score(y_test, y_pred_rf)
roc_xgb = roc_auc_score(y_test, y_pred_xgb)

# R² Scores (for comparison only)
r2_lr = r2_score(y_test, y_pred_lr)
r2_rf = r2_score(y_test, y_pred_rf)
r2_xgb = r2_score(y_test, y_pred_xgb)

# Display results in a table
results = pd.DataFrame({
    'Model': ['Logistic Regression', 'Random Forest', 'XGBoost'],
    'Accuracy': [acc_lr, acc_rf, acc_xgb],
    'ROC_AUC': [roc_lr, roc_rf, roc_xgb],
    'R2_Score': [r2_lr, r2_rf, r2_xgb]
})

print("🔹 Model Comparison:")
print(results)

# Optional: Detailed classification report
print("\nLogistic Regression Report:\n", classification_report(y_test, y_pred_lr))
print("\nRandom Forest Report:\n", classification_report(y_test, y_pred_rf))
print("\nXGBoost Report:\n", classification_report(y_test, y_pred_xgb))
# Out:
# C:\Users\NICE\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\training.py:199: UserWarning: [09:32:58] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# 🔹 Model Comparison:
#                  Model  Accuracy   ROC_AUC  R2_Score
# 0  Logistic Regression  0.993333  0.995968  0.953474
# 1        Random Forest  1.000000  1.000000  1.000000
# 2              XGBoost  1.000000  1.000000  1.000000
#
# Logistic Regression Report:
#                precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        52
#            1       1.00      0.99      1.00       248
#
#     accuracy                           0.99       300
#    macro avg       0.98      1.00      0.99       300
# weighted avg       0.99      0.99      0.99       300
#
#
# Random Forest Report:
#                precision    recall  f1-score   support
#
# ...

# %% [markdown]
# # Rough Work

# %% [markdown]
# # Example Output (Simulated)
# Feature	Importance (%)
# Interaction_score
# policy_annual_premium
# Seniority
# Claim_ratio
# Customer_age
# Policy_tenure
# Driving_experience
# Payment_history_On-time
# umbrella_limit
# Distribution_channel_A

# %%
df
# Out:
#       ID Date_start_contract Date_last_renewal Date_next_renewal Date_birth  \
# 0      1           11/5/2015         11/5/2015         11/5/2016  4/15/1956
# 1      1           11/5/2015         11/5/2016         11/5/2017  4/15/1956
# 2      1           11/5/2015         11/5/2017         11/5/2018  4/15/1956
# 3      1           11/5/2015         11/5/2018         11/5/2019  4/15/1956
# 4      2           9/26/2017         9/26/2017         9/26/2018  4/15/1956
# ..   ...                 ...               ...               ...        ...
# 995  498           11/2/2017         11/2/2017         11/2/2018  8/15/1957
# 996  498           11/2/2017         11/2/2018         11/2/2019  8/15/1957
# 997  499           3/13/2012         3/13/2016         3/13/2017  12/1/1957
# 998  499           3/13/2012         3/13/2017         3/13/2018  12/1/1957
# 999  500           2/19/2018         2/19/2018         2/19/2019  9/20/1957
#
# ...

# %%
# Vehicle_ID
df['Vehicle_ID'] = df['auto_make'].astype(str) + "_" + df['auto_model'].astype(str) + "_" + df['auto_year'].astype(str) + "_" + df['policy_number'].astype(str)

# Payment_history (simulated)
df['Payment_history'] = np.where(df['policy_annual_premium'] > 1000, 'On-time',
                          np.where(df['policy_annual_premium'] > 500, 'Late', 'Missed'))

# Interaction_score
df['Interaction_score'] = (
    df['authorities_contacted'].apply(lambda x: 1 if x == 'Yes' else 0) +
    df['witnesses'].fillna(0) +
    df['police_report_available'].apply(lambda x: 1 if x == 'Yes' else 0)
)

# Renewed (simulated)
df['Renewed'] = np.where(
    (df['Seniority'] > 2) & (df['policy_annual_premium'] > 500),
    1, 0
)
df
# Out:
#       ID Date_start_contract Date_last_renewal Date_next_renewal Date_birth  \
# 0      1           11/5/2015         11/5/2015         11/5/2016  4/15/1956
# 1      1           11/5/2015         11/5/2016         11/5/2017  4/15/1956
# 2      1           11/5/2015         11/5/2017         11/5/2018  4/15/1956
# 3      1           11/5/2015         11/5/2018         11/5/2019  4/15/1956
# 4      2           9/26/2017         9/26/2017         9/26/2018  4/15/1956
# ..   ...                 ...               ...               ...        ...
# 995  498           11/2/2017         11/2/2017         11/2/2018  8/15/1957
# 996  498           11/2/2017         11/2/2018         11/2/2019  8/15/1957
# 997  499           3/13/2012         3/13/2016         3/13/2017  12/1/1957
# 998  499           3/13/2012         3/13/2017         3/13/2018  12/1/1957
# 999  500           2/19/2018         2/19/2018         2/19/2019  9/20/1957
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize encoder
le = LabelEncoder()

# Apply label encoding
df['Payment_history_encoded'] = le.fit_transform(df['Payment_history'])

df
# Out:
#       ID Date_start_contract Date_last_renewal Date_next_renewal Date_birth  \
# 0      1           11/5/2015         11/5/2015         11/5/2016  4/15/1956
# 1      1           11/5/2015         11/5/2016         11/5/2017  4/15/1956
# 2      1           11/5/2015         11/5/2017         11/5/2018  4/15/1956
# 3      1           11/5/2015         11/5/2018         11/5/2019  4/15/1956
# 4      2           9/26/2017         9/26/2017         9/26/2018  4/15/1956
# ..   ...                 ...               ...               ...        ...
# 995  498           11/2/2017         11/2/2017         11/2/2018  8/15/1957
# 996  498           11/2/2017         11/2/2018         11/2/2019  8/15/1957
# 997  499           3/13/2012         3/13/2016         3/13/2017  12/1/1957
# 998  499           3/13/2012         3/13/2017         3/13/2018  12/1/1957
# 999  500           2/19/2018         2/19/2018         2/19/2019  9/20/1957
#
# ...

# %%
df.head(4)
# Out:
#    ID Date_start_contract Date_last_renewal Date_next_renewal Date_birth  \
# 0   1           11/5/2015         11/5/2015         11/5/2016  4/15/1956
# 1   1           11/5/2015         11/5/2016         11/5/2017  4/15/1956
# 2   1           11/5/2015         11/5/2017         11/5/2018  4/15/1956
# 3   1           11/5/2015         11/5/2018         11/5/2019  4/15/1956
#
#   Date_driving_licence  Distribution_channel  Seniority  Policies_in_force  \
# 0            3/20/1976                     0          4                  1
# 1            3/20/1976                     0          4                  1
# 2            3/20/1976                     0          4                  2
# 3            3/20/1976                     0          4                  2
#
#    Max_policies  ...  auto_make  auto_model  auto_year  \
# 0             2  ...       Saab         92x       2004
# 1             2  ...   Mercedes        E400       2007
# ...

# %%
# Step 1: Import Libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score, r2_score
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

# Step 2: Load Dataset
df = pd.read_csv("Insurance_dataSet.csv")

# Step 3: Feature Engineering
df['Claim_ratio'] = df['total_claim_amount'] / df['policy_annual_premium']
df['Interaction_score'] = (
    df['authorities_contacted'].apply(lambda x: 1 if x == 'Yes' else 0) +
    df['witnesses'].fillna(0) +
    df['police_report_available'].apply(lambda x: 1 if x == 'Yes' else 0)
)
df['Renewed'] = np.where((df['Seniority'] > 2) & (df['policy_annual_premium'] > 500), 1, 0)

# Step 4: Date-Based Features
df['Date_birth'] = pd.to_datetime(df['Date_birth'])
df['Date_driving_licence'] = pd.to_datetime(df['Date_driving_licence'])
df['Date_start_contract'] = pd.to_datetime(df['Date_start_contract'])

df['Customer_age'] = (pd.to_datetime('today') - df['Date_birth']).dt.days // 365
df['Driving_experience'] = (pd.to_datetime('today') - df['Date_driving_licence']).dt.days // 365
df['Policy_tenure'] = (pd.to_datetime('today') - df['Date_start_contract']).dt.days // 365

# Simulate Payment_history based on policy_annual_premium
df['Payment_history'] = np.where(df['policy_annual_premium'] > 1000, 'On-time',
                          np.where(df['policy_annual_premium'] > 500, 'Late', 'Missed'))

# Step 5: Label Encode Payment_history
le = LabelEncoder()
df['Payment_history_encoded'] = le.fit_transform(df['Payment_history'])

# Step 6: Select Features and Target
X = df[[
    'policy_annual_premium', 'total_claim_amount', 'Interaction_score',
    'Seniority', 'Policies_in_force', 'umbrella_limit',
    'Customer_age', 'Policy_tenure', 'Driving_experience', 'Claim_ratio',
    'Payment_history_encoded'
]]

y = df['Renewed']

# Step 7: Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Step 8: Initialize and Train Models
model_lr = LogisticRegression(max_iter=500)
model_rf = RandomForestClassifier(n_estimators=200, random_state=42)
model_xgb = XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42)

model_lr.fit(X_train, y_train)
model_rf.fit(X_train, y_train)
model_xgb.fit(X_train, y_train)

# Step 9: Predictions
y_pred_lr = model_lr.predict(X_test)
y_pred_rf = model_rf.predict(X_test)
y_pred_xgb = model_xgb.predict(X_test)

# Step 10: Evaluation Metrics
results = pd.DataFrame({
    'Model': ['Logistic Regression', 'Random Forest', 'XGBoost'],
    'Accuracy': [accuracy_score(y_test, y_pred_lr), accuracy_score(y_test, y_pred_rf), accuracy_score(y_test, y_pred_xgb)],
    'ROC_AUC': [roc_auc_score(y_test, y_pred_lr), roc_auc_score(y_test, y_pred_rf), roc_auc_score(y_test, y_pred_xgb)],
    'R2_Score': [r2_score(y_test, y_pred_lr), r2_score(y_test, y_pred_rf), r2_score(y_test, y_pred_xgb)]
})
print("🔹 Model Comparison:\n", results)

print("\n📊 Logistic Regression Report:\n", classification_report(y_test, y_pred_lr))
print("\n📊 Random Forest Report:\n", classification_report(y_test, y_pred_rf))
print("\n📊 XGBoost Report:\n", classification_report(y_test, y_pred_xgb))

# Step 11: Predict Renewal Probabilities with Best Model (XGBoost)
df['Renewal_Probability'] = model_xgb.predict_proba(X)[:, 1]

# Step 12: Segment Customers by Risk
df['Renewal_Risk'] = pd.cut(df['Renewal_Probability'],
                            bins=[0, 0.4, 0.7, 1.0],
                            labels=['High Risk', 'Medium Risk', 'Low Risk'])

# Step 13: Feature Importance (Random Forest)
importances = model_rf.feature_importances_
importance_percent = 100 * importances / importances.sum()
importance_df = pd.DataFrame({
    'Feature': X.columns,
    'Importance (%)': importance_percent
}).sort_values(by='Importance (%)', ascending=False)

print("\n🔝 Top Feature Importances (%):\n", importance_df.head(10))

# Optional: Plot Feature Importance
plt.figure(figsize=(10, 6))
plt.barh(importance_df['Feature'][:10], importance_df['Importance (%)'][:10])
plt.gca().invert_yaxis()
plt.title("Top 10 Feature Importances")
plt.xlabel("Importance (%)")
plt.show()

# Step 14: Save Final Dataset
df.to_csv("Insurance_dataSet_with_predictions.csv", index=False)
# Out:
# C:\Users\NICE\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 500 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=500).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\NICE\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\training.py:199: UserWarning: [09:33:03] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# 🔹 Model Comparison:
# ...

# %%
# Step 1: Import Libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

# Step 2: Load Dataset
df = pd.read_csv("Insurance_dataSet.csv")

# Step 3: Feature Engineering
df['Claim_ratio'] = df['total_claim_amount'] / df['policy_annual_premium']
df['Interaction_score'] = (
    df['authorities_contacted'].apply(lambda x: 1 if x == 'Yes' else 0) +
    df['witnesses'].fillna(0) +
    df['police_report_available'].apply(lambda x: 1 if x == 'Yes' else 0)
)
df['Renewed'] = np.where((df['Seniority'] > 2) & (df['policy_annual_premium'] > 500), 1, 0)

# Step 4: Date-Based Features
df['Date_birth'] = pd.to_datetime(df['Date_birth'])
df['Date_driving_licence'] = pd.to_datetime(df['Date_driving_licence'])
df['Date_start_contract'] = pd.to_datetime(df['Date_start_contract'])

df['Customer_age'] = (pd.to_datetime('today') - df['Date_birth']).dt.days // 365
df['Driving_experience'] = (pd.to_datetime('today') - df['Date_driving_licence']).dt.days // 365
df['Policy_tenure'] = (pd.to_datetime('today') - df['Date_start_contract']).dt.days // 365

# Step 5: Simulate and Encode Payment_history
df['Payment_history'] = np.where(df['policy_annual_premium'] > 1000, 'On-time',
                          np.where(df['policy_annual_premium'] > 500, 'Late', 'Missed'))
le = LabelEncoder()
df['Payment_history_encoded'] = le.fit_transform(df['Payment_history'])

# Step 6: Select Features and Target
X = df[[
    'policy_annual_premium', 'total_claim_amount', 'Interaction_score',
    'Seniority', 'Policies_in_force', 'umbrella_limit',
    'Customer_age', 'Policy_tenure', 'Driving_experience', 'Claim_ratio',
    'Payment_history_encoded'
]]
y = df['Renewed']

# Step 7: Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Step 8: Train XGBoost Model
model_xgb = XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42)
model_xgb.fit(X_train, y_train)

# Step 9: Predictions and Evaluation
y_pred = model_xgb.predict(X_test)
y_proba = model_xgb.predict_proba(X_test)[:, 1]

print("✅ Accuracy:", accuracy_score(y_test, y_pred))
print("📊 ROC-AUC Score:", roc_auc_score(y_test, y_pred))
print("📋 Classification Report:\n", classification_report(y_test, y_pred))

# Step 10: Predict Renewal Probabilities for All Customers
df['Renewal_Probability'] = model_xgb.predict_proba(X)[:, 1]

# Step 11: Segment Customers by Risk
df['Renewal_Risk'] = pd.cut(df['Renewal_Probability'],
                            bins=[0, 0.4, 0.7, 1.0],
                            labels=['High Risk', 'Medium Risk', 'Low Risk'])

# Step 12: Save Final Dataset
df.to_csv("Insurance_dataSet_with_XGBoost_predictions.csv", index=False)
# Out:
# C:\Users\NICE\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\training.py:199: UserWarning: [09:33:05] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# ✅ Accuracy: 1.0
# 📊 ROC-AUC Score: 1.0
# 📋 Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        52
#            1       1.00      1.00      1.00       248
#
#     accuracy                           1.00       300
#    macro avg       1.00      1.00      1.00       300
# weighted avg       1.00      1.00      1.00       300

# %%
# Import libraries
import pandas as pd
import numpy as np
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score, classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv("Insurance_dataSet.csv")

# Feature engineering
df['Claim_ratio'] = df['total_claim_amount'] / df['policy_annual_premium']
df['Interaction_score'] = (
    df['authorities_contacted'].apply(lambda x: 1 if x == 'Yes' else 0) +
    df['witnesses'].fillna(0) +
    df['police_report_available'].apply(lambda x: 1 if x == 'Yes' else 0)
)
df['Renewed'] = np.where((df['Seniority'] > 2) & (df['policy_annual_premium'] > 500), 1, 0)

# Date-based features
df['Date_birth'] = pd.to_datetime(df['Date_birth'])
df['Date_driving_licence'] = pd.to_datetime(df['Date_driving_licence'])
df['Date_start_contract'] = pd.to_datetime(df['Date_start_contract'])
df['Customer_age'] = (pd.to_datetime('today') - df['Date_birth']).dt.days // 365
df['Driving_experience'] = (pd.to_datetime('today') - df['Date_driving_licence']).dt.days // 365
df['Policy_tenure'] = (pd.to_datetime('today') - df['Date_start_contract']).dt.days // 365

# Simulate and encode Payment_history
df['Payment_history'] = np.where(df['policy_annual_premium'] > 1000, 'On-time',
                          np.where(df['policy_annual_premium'] > 500, 'Late', 'Missed'))
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Payment_history_encoded'] = le.fit_transform(df['Payment_history'])

# Select features and target
X = df[[
    'policy_annual_premium', 'total_claim_amount', 'Interaction_score',
    'Seniority', 'Policies_in_force', 'umbrella_limit',
    'Customer_age', 'Policy_tenure', 'Driving_experience', 'Claim_ratio',
    'Payment_history_encoded'
]]
y = df['Renewed']

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train XGBoost model
model_xgb = XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42)
model_xgb.fit(X_train, y_train)

# Predictions
y_pred = model_xgb.predict(X_test)
y_proba = model_xgb.predict_proba(X_test)[:, 1]

# Evaluation
print("✅ Accuracy:", accuracy_score(y_test, y_pred))
print("📊 ROC-AUC Score:", roc_auc_score(y_test, y_pred))
print("📋 Classification Report:\n", classification_report(y_test, y_pred))

# Compare predictions vs actuals
comparison_df = pd.DataFrame({
    'Actual': y_test.values,
    'Predicted': y_pred,
    'Probability': y_proba
})
print("🔍 Prediction Comparison:\n", comparison_df.head(10))

# Confusion matrix
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# Misclassified samples
misclassified = comparison_df[comparison_df['Actual'] != comparison_df['Predicted']]
print(" Misclassified Samples:\n", misclassified.head())
# Out:
# C:\Users\NICE\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\training.py:199: UserWarning: [09:33:06] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# ✅ Accuracy: 1.0
# 📊 ROC-AUC Score: 1.0
# 📋 Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        52
#            1       1.00      1.00      1.00       248
#
#     accuracy                           1.00       300
#    macro avg       1.00      1.00      1.00       300
# weighted avg       1.00      1.00      1.00       300
#
# 🔍 Prediction Comparison:
#     Actual  Predicted  Probability
# 0       1          1     0.999691
# 1       1          1     0.999546
# 2       1          1     0.997987
# 3       1          1     0.997796
# 4       1          1     0.996795
# 5       1          1     0.999152
# ...

# %%
# Step 1: Define important features
input_features = [
    'policy_annual_premium', 'total_claim_amount', 'Interaction_score',
    'Seniority', 'Policies_in_force', 'umbrella_limit',
    'Customer_age', 'Policy_tenure', 'Driving_experience', 'Claim_ratio',
    'Payment_history_encoded'
]

# Step 2: Collect user input
user_data = {}
print("🔹 Enter values for the following features:")
for feature in input_features:
    value = float(input(f"{feature}: "))
    user_data[feature] = value

# Step 3: Convert to DataFrame
user_df = pd.DataFrame([user_data])

# Step 4: Predict using trained XGBoost model
renewal_prob = model_xgb.predict_proba(user_df)[0][1]
renewal_pred = model_xgb.predict(user_df)[0]

# Step 5: Display result
print("\n📈 Predicted Renewal Probability:", round(renewal_prob, 4))
print("✅ Predicted Renewal Status:", "Renewed" if renewal_pred == 1 else "Not Renewed")
# Out:
# 🔹 Enter values for the following features:
# policy_annual_premium:  1200
# total_claim_amount:  300
# Interaction_score:  2
# Seniority:  5
# Policies_in_force:  5
# umbrella_limit:  50000
# Customer_age:  45
# Policy_tenure:  5
# Driving_experience:  5
# Claim_ratio:  2
# Payment_history_encoded:  1
# 📈 Predicted Renewal Probability: 0.978
# ✅ Predicted Renewal Status: Renewed

# %%
df['Renewal_Probability'] = model_xgb.predict_proba(X)[:, 1]

# %%
import joblib

# Save the trained XGBoost model to a file
joblib.dump(model_xgb, "xgboost_insurance_model.pkl")

print("✅ Model saved as 'xgboost_insurance_model.pkl'")
# Out:
# ✅ Model saved as 'xgboost_insurance_model.pkl'

# %%
# Load the saved model
loaded_model = joblib.load("xgboost_insurance_model.pkl")

# Predict using loaded model
new_predictions = loaded_model.predict(X_test)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb

# Ensure predictions and risk segmentation are done
df['Renewal_Probability'] = model_xgb.predict_proba(X)[:, 1]
df['Renewal_Risk'] = pd.cut(df['Renewal_Probability'],
                            bins=[0, 0.4, 0.7, 1.0],
                            labels=['High Risk', 'Medium Risk', 'Low Risk'])

# Create comparison DataFrame
comparison_df = pd.DataFrame({
    'Actual': y_test.values,
    'Predicted': model_xgb.predict(X_test),
    'Probability': model_xgb.predict_proba(X_test)[:, 1]
})

# Confusion matrix
cm = confusion_matrix(y_test, comparison_df['Predicted'])

# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(14, 10))
fig.suptitle("📊 Insurance Renewal Model Visual Summary", fontsize=16)

# 1. Feature Importance
xgb.plot_importance(model_xgb, ax=axs[0, 0], max_num_features=10, importance_type='weight')
axs[0, 0].set_title("Feature Importance")

# 2. Renewal Probability Distribution
axs[0, 1].hist(df['Renewal_Probability'], bins=20, color='skyblue', edgecolor='black')
axs[0, 1].set_title("Renewal Probability Distribution")
axs[0, 1].set_xlabel("Probability")
axs[0, 1].set_ylabel("Customer Count")

# 3. Risk Segmentation Pie Chart
risk_counts = df['Renewal_Risk'].value_counts()
axs[1, 0].pie(risk_counts, labels=risk_counts.index, autopct='%1.1f%%', colors=['red', 'orange', 'green'])
axs[1, 0].set_title("Risk Segmentation")

# 4. Confusion Matrix
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=axs[1, 1])
axs[1, 1].set_title("Confusion Matrix")
axs[1, 1].set_xlabel("Predicted")
axs[1, 1].set_ylabel("Actual")

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()
# Out:
# C:\Users\NICE\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# C:\Users\NICE\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # Example Input Prompt
#  ### policy_annual_premium: 1200
# ### total_claim_amount: 300
# ### Interaction_score: 2
# ### Seniority: 5
# ### Policies_in_force: 3
# ### umbrella_limit: 500000
# #### Customer_age: 45
# ### Policy_tenure: 3
# ### Driving_experience: 20
# ### Claim_ratio: 0.25
# ### Payment_history_encoded: 2

# %% [markdown]
# # 📊 1. Feature Importance (from XGBoost)

# %%
import matplotlib.pyplot as plt
import xgboost as xgb

# Plot feature importance
xgb.plot_importance(model_xgb, max_num_features=10, importance_type='weight')
plt.title("Top 10 Feature Importances (XGBoost)")
plt.show()

# %% [markdown]
# # 📈 2. Renewal Probability Distribution

# %%
print(df['Renewal_Probability'].describe())
# Out:
# count    1000.000000
# mean        0.815767
# std         0.384008
# min         0.000775
# 25%         0.993933
# 50%         0.999000
# 75%         0.999689
# max         0.999872
# Name: Renewal_Probability, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
plt.hist(df['Renewal_Probability'], bins=20, color='skyblue', edgecolor='black')
plt.title("Distribution of Renewal Probabilities")
plt.xlabel("Renewal Probability")
plt.ylabel("Number of Customers")
plt.grid(True)
plt.show()

# %% [markdown]
# # 📊 3. Risk Segmentation Pie Chart

# %%
# Predict renewal probabilities
df['Renewal_Probability'] = model_xgb.predict_proba(X)[:, 1]

# Segment customers by risk
df['Renewal_Risk'] = pd.cut(df['Renewal_Probability'],
                            bins=[0, 0.4, 0.7, 1.0],
                            labels=['High Risk', 'Medium Risk', 'Low Risk'])

# %%
import matplotlib.pyplot as plt

risk_counts = df['Renewal_Risk'].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(risk_counts, labels=risk_counts.index, autopct='%1.1f%%', colors=['red', 'orange', 'green'])
plt.title("Customer Risk Segmentation")
plt.show()

# %% [markdown]
# # 📉 4. Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

cm = confusion_matrix(y_test, model_xgb.predict(X_test))
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# # 📊 5. Actual vs Predicted Comparison

# %%
comparison_df = pd.DataFrame({
    'Actual': y_test.values,
    'Predicted': model_xgb.predict(X_test),
    'Probability': model_xgb.predict_proba(X_test)[:, 1]
})

plt.figure(figsize=(10, 5))
plt.scatter(range(len(comparison_df)), comparison_df['Probability'], c=comparison_df['Actual'], cmap='coolwarm', alpha=0.6)
plt.title("Predicted Probabilities vs Actual Labels")
plt.xlabel("Sample Index")
plt.ylabel("Renewal Probability")
plt.colorbar(label='Actual Label')
plt.show()
